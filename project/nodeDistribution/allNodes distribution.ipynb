# %%
import pathlib
import os

import pandas as pd

import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

import numpy as np
import geopandas as gpd
from shapely.geometry import Point

# %% [markdown]
# 1、Here is the data about the node.

# %% [markdown]
# （1）Read node information from nodes.csv

# %%
allNodes = pd.read_csv('.../nodes.csv')
allNodes.head(15)
# Out:
#          node_id   project_id  vsn  \
# 0   001e0610ba46  AoT_Chicago  004
# 1   001e0610ba3b  AoT_Chicago  006
# 2   001e0610f02f  AoT_Chicago  00A
# 3   001e0610ba8f  AoT_Chicago  00D
# 4   001e0610ba16  AoT_Chicago  010
# 5   001e06107e5d  AoT_Chicago  014
# 6   001e0610ba8b  AoT_Chicago  018
# 7   001e0610ba13  AoT_Chicago  01C
# 8   001e0610ba18  AoT_Chicago  01D
# 9   001e0610bc10  AoT_Chicago  01F
# 10  001e0610bbf9  AoT_Chicago  020
# 11  001e0610bbff  AoT_Chicago  025
# 12  001e0610b9e7  AoT_Chicago  028
# 13  001e0610ba15  AoT_Chicago  02A
# 14  001e0610bbe5  AoT_Chicago  02C
#
#                                         address        lat        lon  \
# 0            State St & Jackson Blvd Chicago IL  41.878377 -87.627678
# 1            18th St & Lake Shore Dr Chicago IL  41.858136 -87.616055
# 2   Lake Shore Drive & Fullerton Ave Chicago IL  41.926261 -87.630758
# 3                  Cornell & 47th St Chicago IL  41.810342 -87.590228
# 4           Homan Ave & Roosevelt Rd Chicago IL  41.866349 -87.710543
# 5           State St & Washington St Chicago IL  41.883205 -87.627769
# 6         Stony Island Ave & 63rd St Chicago IL  41.780600 -87.586456
# 7                7801 S Lawndale Ave Chicago IL  41.751238 -87.712990
# 8                 Damen Ave & Cermak Chicago IL  41.852179 -87.675825
# 9                    State St & 87th Chicago IL  41.736314 -87.624179
# 10             Western Ave & 69th St Chicago IL  41.768319 -87.683396
# 11             Western Ave & 18th St Chicago IL  41.857797 -87.685806
# 12            Western Blvd & 35th St Chicago IL  41.830385 -87.684862
# 13             Jeffrey Ave & 95th St Chicago IL  41.722457 -87.575350
# 14   Martin Luther King Dr & 87th St Chicago IL  41.736495 -87.614529
#
#                     description      start_timestamp end_timestamp
# 0           AoT Chicago (S) [C]  2017/10/09 00:00:00           NaN
# 1               AoT Chicago (S)  2017/08/08 00:00:00           NaN
# 2          AoT Chicago (S) [CA]  2018/05/07 00:00:00           NaN
# 3               AoT Chicago (S)  2017/08/08 00:00:00           NaN
# 4           AoT Chicago (S) [C]  2018/07/18 00:00:00           NaN
# 5               AoT Chicago (T)  2016/09/14 00:00:00           NaN
# 6           AoT Chicago (S) [C]  2018/02/26 00:00:00           NaN
# 7   AoT Chicago (S) [C] {ComEd}  2018/01/01 00:00:00           NaN
# 8               AoT Chicago (S)  2017/12/15 00:00:00           NaN
# 9           AoT Chicago (S) [C]  2018/02/22 00:00:00           NaN
# 10          AoT Chicago (S) [C]  2018/02/13 00:00:00           NaN
# 11              AoT Chicago (S)  2017/12/15 00:00:00           NaN
# 12              AoT Chicago (T)  2017/02/02 00:00:00           NaN
# 13          AoT Chicago (S) [C]  2018/02/22 00:00:00           NaN
# 14          AoT Chicago (S) [C]  2018/02/16 00:00:00           NaN

# %%
allNodes.lon
# Out:
# 0     -87.627678
# 1     -87.616055
# 2     -87.630758
# 3     -87.590228
# 4     -87.710543
#          ...
# 121   -87.659467
# 122   -87.659467
# 123   -87.659467
# 124   -87.659467
# 125   -87.600008
# Name: lon, Length: 126, dtype: float64

# %% [markdown]
# （2）According to the statistics, there are 126 pieces of data, and each data has 9 attributes.

# %%
allNodes.shape
# Out:
# (126, 9)

# %%
soundNodes = pd.read_csv('.../soundNodes.csv')
soundNodes.head(15)
# Out:
#          node_id   project_id  vsn  \
# 0   001e0610ba46  AoT_Chicago  004
# 1   001e0610ba13  AoT_Chicago  01C
# 2   001e0610bc10  AoT_Chicago  01F
# 3   001e0610ba15  AoT_Chicago  02A
# 4   001e0610bbe5  AoT_Chicago  02C
# 5   001e0610ee36  AoT_Chicago  051
# 6   001e0610ee5d  AoT_Chicago  056
# 7   001e06113ad8  AoT_Chicago  062
# 8   001e0611441e  AoT_Chicago  067
# 9   001e06112e77  AoT_Chicago  06B
# 10  001e0610f6db  AoT_Chicago  06D
# 11  001e06113107  AoT_Chicago  072
# 12  001e06113ace  AoT_Chicago  077
# 13  001e06113a24  AoT_Chicago  07A
# 14  001e061144cd  AoT_Chicago  07B
#
#                                        address        lat        lon  \
# 0           State St & Jackson Blvd Chicago IL  41.878377 -87.627678
# 1               7801 S Lawndale Ave Chicago IL  41.751238 -87.712990
# 2                   State St & 87th Chicago IL  41.736314 -87.624179
# 3             Jeffrey Ave & 95th St Chicago IL  41.722457 -87.575350
# 4   Martin Luther King Dr & 87th St Chicago IL  41.736495 -87.614529
# 5       Cottage Grove Ave & 79th St Chicago IL  41.751295 -87.605288
# 6          Long Ave & Fullerton Ave Chicago IL  41.923996 -87.761072
# 7        Ashland Ave & Roosevelt Rd Chicago IL  41.866786 -87.666306
# 8                Ashland Ave & 47th Chicago IL  41.808594 -87.665048
# 9             Ashland Ave & 59th St Chicago IL  41.786756 -87.664343
# 10      Hutchinson Commons UChicago Chicago IL  41.791329 -87.598677
# 11              7801 S Lawndale Ave Chicago IL  41.751142 -87.712990
# 12  Martin Luther King Dr & 35th St Chicago IL  41.831070 -87.617298
# 13        UChicago, Oriental Museum Chicago IL  41.788979 -87.597995
# 14        Ashland Ave & Harrison St Chicago IL  41.874200 -87.666599
#
#                        description      start_timestamp  end_timestamp
# 0              AoT Chicago (S) [C]  2017/10/09 00:00:00            NaN
# 1      AoT Chicago (S) [C] {ComEd}  2018/01/01 00:00:00            NaN
# 2              AoT Chicago (S) [C]  2018/02/22 00:00:00            NaN
# 3              AoT Chicago (S) [C]  2018/02/22 00:00:00            NaN
# 4              AoT Chicago (S) [C]  2018/02/16 00:00:00            NaN
# 5              AoT Chicago (S) [C]  2018/02/22 00:00:00            NaN
# 6              AoT Chicago (S) [C]  2018/02/23 00:00:00            NaN
# 7              AoT Chicago (S) [C]  2018/02/27 00:00:00            NaN
# 8              AoT Chicago (S) [C]  2018/02/27 00:00:00            NaN
# 9              AoT Chicago (S) [C]  2018/02/26 00:00:00            NaN
# 10  AoT Chicago (S) [C] {UChicago}  2018/03/15 00:00:00            NaN
# 11    AoT Chicago (S) [CA] {ComEd}  2017/01/01 00:00:00            NaN
# 12             AoT Chicago (S) [C]  2018/03/08 00:00:00            NaN
# 13  AoT Chicago (S) [C] {UChicago}  2018/04/12 00:00:00            NaN
# 14             AoT Chicago (S) [C]  2018/05/31 00:00:00            NaN

# %%
soundNodes.shape
# Out:
# (35, 9)

# %%
soundNodes_notWorking = pd.read_csv('.../soundNode_notWorking.csv')
soundNodes_notWorking
# Out:
#         node_id   project_id  vsn                                address  \
# 0  001e0610fb4c  AoT_Chicago  04D  Leavitt St & Milwaukee Ave Chicago IL
#
#          lat        lon      description      start_timestamp  end_timestamp
# 0  41.913583 -87.682414  AoT Chicago (S)  2017/10/09 00:00:00            NaN

# %% [markdown]
# （1）Set global variables for shape files for Chicago streets and districts.

# %%
#
Chicago_Streets_Shapefiles = '.../street-chicago.shp'
Chicago_Boundary_Shapefile = '.../il-chicago.shp'

# %%
plt.style.use('default')

# Read street information
streetmap = gpd.read_file(Chicago_Streets_Shapefiles)
f, ax = plt.subplots(1, figsize=(15, 15))

# Draw the streets of Chicago
streetmap.plot(ax=ax, color='silver', zorder = 0)

# Read boundary information
boundary = gpd.read_file(Chicago_Boundary_Shapefile)
# Draw the boundaries of Chicago
boundary.plot(ax=ax, color='white', alpha = 0.4, linewidth=5.5, edgecolor='red', zorder = 5)

ax.plot(allNodes['lon'],allNodes['lat'], marker='v', color="skyblue",linestyle='', ms=5, zorder = 10,label="Other nodes")
ax.plot(soundNodes['lon'],soundNodes['lat'], marker='v', color="sandybrown",linestyle='', ms=5, zorder = 10,label="Sound nodes")
ax.plot(soundNodes_notWorking['lon'],soundNodes_notWorking['lat'], marker='v', color="black",linestyle='', ms=5, zorder = 10,label="Sound node(not working)")

# ax.legend(), set legend
ax.legend(loc="lower left",fontsize=12)

# Turn off the X and Y axes
ax.set_axis_off()
ax.set_title('Spatial distrinution for AoT nodes in Chicago', fontsize = 18, fontdict = {'verticalalignment':'bottom'})
# Out:
# Text(0.5, 1.0, 'Spatial distrinution for AoT nodes in Chicago')
